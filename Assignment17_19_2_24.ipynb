# %% [markdown]
# <a href="https://colab.research.google.com/github/A-THAKUR22/AVISOFTAT/blob/main/Assignment17_19_2_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python pandas Practice Problems - UC Berkeley MIDS notebook
#
# Importing Data and Making a DataFrame
# The statsmodels package (installed in the code cell above) includes built-in datasets. Execute the code below to download data from the American National Election Studies of 1996 and print a detailed description of the schema.
#
# The next cell extracts the Dataset object from the submodule and saves the DataFrame to the variable df. In the questions that follow, use df when referencing the dataset.

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

anes96 = sm.datasets.anes96
print(anes96.NOTE)

dataset_anes96 = anes96.load_pandas()
df = dataset_anes96.data
df
# Out:
# ::
#
#     Number of observations - 944
#     Number of variables - 10
#
#     Variables name definitions::
#
#             popul - Census place population in 1000s
#             TVnews - Number of times per week that respondent watches TV news.
#             PID - Party identification of respondent.
#                 0 - Strong Democrat
#                 1 - Weak Democrat
#                 2 - Independent-Democrat
#                 3 - Independent-Indpendent
#                 4 - Independent-Republican
#                 5 - Weak Republican
#                 6 - Strong Republican
#             age : Age of respondent.
#             educ - Education level of respondent
#                 1 - 1-8 grades
#                 2 - Some high school
#                 3 - High school graduate
#                 4 - Some college
#                 5 - College degree
#                 6 - Master's degree
#                 7 - PhD
#             income - Income of household
#                 1  - None or less than $2,999
#                 2  - $3,000-$4,999
#                 3  - $5,000-$6,999
#                 4  - $7,000-$8,999
#                 5  - $9,000-$9,999
#                 6  - $10,000-$10,999
#                 7  - $11,000-$11,999
#                 8  - $12,000-$12,999
#                 9  - $13,000-$13,999
#                 10 - $14,000-$14.999
#                 11 - $15,000-$16,999
#                 12 - $17,000-$19,999
#                 13 - $20,000-$21,999
#                 14 - $22,000-$24,999
#                 15 - $25,000-$29,999
#                 16 - $30,000-$34,999
#                 17 - $35,000-$39,999
#                 18 - $40,000-$44,999
#                 19 - $45,000-$49,999
#                 20 - $50,000-$59,999
#                 21 - $60,000-$74,999
#                 22 - $75,000-89,999
#                 23 - $90,000-$104,999
#                 24 - $105,000 and over
#             vote - Expected vote
#                 0 - Clinton
#                 1 - Dole
#             The following 3 variables all take the values:
#                 1 - Extremely liberal
#                 2 - Liberal
#                 3 - Slightly liberal
#                 4 - Moderate
#                 5 - Slightly conservative
#                 6 - Conservative
#                 7 - Extremely Conservative
#             selfLR - Respondent's self-reported political leanings from "Left"
#                 to "Right".
#             ClinLR - Respondents impression of Bill Clinton's political
#                 leanings from "Left" to "Right".
#             DoleLR  - Respondents impression of Bob Dole's political leanings
#                 from "Left" to "Right".
#             logpopul - log(popul + .1)
#      popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  income  vote  \
# 0      0.0     7.0     7.0     1.0     6.0  6.0  36.0   3.0     1.0   1.0
# 1    190.0     1.0     3.0     3.0     5.0  1.0  20.0   4.0     1.0   0.0
# 2     31.0     7.0     2.0     2.0     6.0  1.0  24.0   6.0     1.0   0.0
# 3     83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0     1.0   0.0
# 4    640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0     1.0   0.0
# ..     ...     ...     ...     ...     ...  ...   ...   ...     ...   ...
# 939    0.0     7.0     7.0     1.0     6.0  4.0  73.0   6.0    24.0   1.0
# 940    0.0     7.0     5.0     2.0     6.0  6.0  50.0   6.0    24.0   1.0
# 941    0.0     3.0     6.0     2.0     7.0  5.0  43.0   6.0    24.0   1.0
# 942    0.0     6.0     6.0     2.0     5.0  6.0  46.0   7.0    24.0   1.0
# 943   18.0     7.0     4.0     2.0     6.0  3.0  61.0   7.0    24.0   1.0
#
#      logpopul
# 0   -2.302585
# 1    5.247550
# 2    3.437208
# 3    4.420045
# 4    6.461624
# ..        ...
# 939 -2.302585
# 940 -2.302585
# 941 -2.302585
# 942 -2.302585
# 943  2.895912
#
# [944 rows x 11 columns]

# %%
df.shape
# Out:
# (944, 11)

# %% [markdown]
# Q1 DataFrame Basic Properties Exercise
# Our DataFrame (df) contains data on registered voters in the United States, including demographic information and political preference. Using pandas, print the first 5 rows of the DataFrame to get a sense of what the data looks like. Next, answer the following questions:
#
# How many observations are in the DataFrame?
# How many variables are measured (how many columns)?
# What is the age of the youngest person in the data? The oldest?
# How many days a week does the average respondent watch TV news (round to the nearest tenth)?
# Check for missing values. Are there any?

# %%
sample=df.head(5)
sample
# Out:
#    popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  income  vote  \
# 0    0.0     7.0     7.0     1.0     6.0  6.0  36.0   3.0     1.0   1.0
# 1  190.0     1.0     3.0     3.0     5.0  1.0  20.0   4.0     1.0   0.0
# 2   31.0     7.0     2.0     2.0     6.0  1.0  24.0   6.0     1.0   0.0
# 3   83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0     1.0   0.0
# 4  640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0     1.0   0.0
#
#    logpopul
# 0 -2.302585
# 1  5.247550
# 2  3.437208
# 3  4.420045
# 4  6.461624

# %%
youngest=sample['age'].min()
eldest=sample['age'].max()
print(f"The youngest person in the data is {youngest}")
print(f"The eldest person in the data is {eldest}")
# Out:
# The youngest person in the data is 20.0
# The eldest person in the data is 68.0

# %%
df.columns
# Out:
# Index(['popul', 'TVnews', 'selfLR', 'ClinLR', 'DoleLR', 'PID', 'age', 'educ',
#        'income', 'vote', 'logpopul'],
#       dtype='object')

# %%
#How many days a week does the average respondent watch TV news (round to the nearest tenth)
average=df['TVnews'].mean()
avg=round(average,10)
avg
# Out:
# 3.7277542373

# %%
df.isnull().sum()
# Out:
# popul       0
# TVnews      0
# selfLR      0
# ClinLR      0
# DoleLR      0
# PID         0
# age         0
# educ        0
# income      0
# vote        0
# logpopul    0
# dtype: int64

# %% [markdown]
# Q2Data Processing Exercise
# We want to adjust the dataset for our use. Do the following:
#
# Rename the educ column education.
# Create a new column called party based on each respondent's answer to PID. party should equal Democrat if the respondent selected either Strong Democrat or Weak Democrat. party will equal Republican if the respondent selected Strong or Weak Republican for PID and Independent if they selected anything else.
# Create a new column called age_group that buckets respondents into the following categories based on their age: 18-24, 25-34, 35-44, 45-54, 55-64, and 65 and over.

# %%
df.rename(columns={'educ':'education'}, inplace=False)
# Out:
#      popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  education  income  \
# 0      0.0     7.0     7.0     1.0     6.0  6.0  36.0        3.0     1.0
# 1    190.0     1.0     3.0     3.0     5.0  1.0  20.0        4.0     1.0
# 2     31.0     7.0     2.0     2.0     6.0  1.0  24.0        6.0     1.0
# 3     83.0     4.0     3.0     4.0     5.0  1.0  28.0        6.0     1.0
# 4    640.0     7.0     5.0     6.0     4.0  0.0  68.0        6.0     1.0
# ..     ...     ...     ...     ...     ...  ...   ...        ...     ...
# 939    0.0     7.0     7.0     1.0     6.0  4.0  73.0        6.0    24.0
# 940    0.0     7.0     5.0     2.0     6.0  6.0  50.0        6.0    24.0
# 941    0.0     3.0     6.0     2.0     7.0  5.0  43.0        6.0    24.0
# 942    0.0     6.0     6.0     2.0     5.0  6.0  46.0        7.0    24.0
# 943   18.0     7.0     4.0     2.0     6.0  3.0  61.0        7.0    24.0
#
#      vote  logpopul
# 0     1.0 -2.302585
# 1     0.0  5.247550
# 2     0.0  3.437208
# 3     0.0  4.420045
# 4     0.0  6.461624
# ..    ...       ...
# 939   1.0 -2.302585
# 940   1.0 -2.302585
# 941   1.0 -2.302585
# 942   1.0 -2.302585
# 943   1.0  2.895912
#
# [944 rows x 11 columns]

# %%
df["party"] = np.select(
    [df["PID"].isin([0, 1]), df["PID"].isin([5, 6]), df["PID"].isin([2, 3, 4])],
    ["Democrat", "Republican", "Independent"],
    default=np.nan
)
df
# Out:
#      popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  income  vote  \
# 0      0.0     7.0     7.0     1.0     6.0  6.0  36.0   3.0     1.0   1.0
# 1    190.0     1.0     3.0     3.0     5.0  1.0  20.0   4.0     1.0   0.0
# 2     31.0     7.0     2.0     2.0     6.0  1.0  24.0   6.0     1.0   0.0
# 3     83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0     1.0   0.0
# 4    640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0     1.0   0.0
# ..     ...     ...     ...     ...     ...  ...   ...   ...     ...   ...
# 939    0.0     7.0     7.0     1.0     6.0  4.0  73.0   6.0    24.0   1.0
# 940    0.0     7.0     5.0     2.0     6.0  6.0  50.0   6.0    24.0   1.0
# 941    0.0     3.0     6.0     2.0     7.0  5.0  43.0   6.0    24.0   1.0
# 942    0.0     6.0     6.0     2.0     5.0  6.0  46.0   7.0    24.0   1.0
# 943   18.0     7.0     4.0     2.0     6.0  3.0  61.0   7.0    24.0   1.0
#
#      logpopul        party
# 0   -2.302585   Republican
# 1    5.247550     Democrat
# 2    3.437208     Democrat
# 3    4.420045     Democrat
# 4    6.461624     Democrat
# ..        ...          ...
# 939 -2.302585  Independent
# 940 -2.302585   Republican
# 941 -2.302585   Republican
# 942 -2.302585   Republican
# 943  2.895912  Independent
#
# [944 rows x 12 columns]

# %%
df["age_group"] = np.select(
    [
        (df["age"] >= 18) & (df["age"] <= 24),
        (df["age"] >= 25) & (df["age"] <= 34),
        (df["age"] >= 35) & (df["age"] <= 44),
        (df["age"] >= 45) & (df["age"] <= 54),
        (df["age"] >= 55) & (df["age"] <= 64),
        (df["age"] >= 65),
    ],
    ["18-24", "25-34", "35-44", "45-54", "55-64", "Above 65"],
)
df
# Out:
#      popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  income  vote  \
# 0      0.0     7.0     7.0     1.0     6.0  6.0  36.0   3.0     1.0   1.0
# 1    190.0     1.0     3.0     3.0     5.0  1.0  20.0   4.0     1.0   0.0
# 2     31.0     7.0     2.0     2.0     6.0  1.0  24.0   6.0     1.0   0.0
# 3     83.0     4.0     3.0     4.0     5.0  1.0  28.0   6.0     1.0   0.0
# 4    640.0     7.0     5.0     6.0     4.0  0.0  68.0   6.0     1.0   0.0
# ..     ...     ...     ...     ...     ...  ...   ...   ...     ...   ...
# 939    0.0     7.0     7.0     1.0     6.0  4.0  73.0   6.0    24.0   1.0
# 940    0.0     7.0     5.0     2.0     6.0  6.0  50.0   6.0    24.0   1.0
# 941    0.0     3.0     6.0     2.0     7.0  5.0  43.0   6.0    24.0   1.0
# 942    0.0     6.0     6.0     2.0     5.0  6.0  46.0   7.0    24.0   1.0
# 943   18.0     7.0     4.0     2.0     6.0  3.0  61.0   7.0    24.0   1.0
#
#      logpopul        party age_group
# 0   -2.302585   Republican     35-44
# 1    5.247550     Democrat     18-24
# 2    3.437208     Democrat     18-24
# 3    4.420045     Democrat     25-34
# 4    6.461624     Democrat  Above 65
# ..        ...          ...       ...
# 939 -2.302585  Independent  Above 65
# 940 -2.302585   Republican     45-54
# 941 -2.302585   Republican     35-44
# 942 -2.302585   Republican     45-54
# 943  2.895912  Independent     55-64
#
# [944 rows x 13 columns]

# %% [markdown]
# Q3. Filtering Data Exercise
# Use the filtering method to find all the respondents who have the impression that Bill Clinton is moderate or conservative (ClinLR equals 4 or higher). How many respondents are in this subset?
#
# Among these respondents, how many have a household income less than $50,000 and attended at least some college?

# %%
new=df[df['ClinLR']>=4]
number_of_respondents=len(new)
number_of_respondents
# Out:
# 282

# %%
Income_attendcollege=new[(new['income']<20) & (new['educ']<=5)]
Number_of_Income_attendcollege=len(Income_attendcollege)
Number_of_Income_attendcollege
# Out:
# 169

# %% [markdown]
# 4. Calculating From Data Exercise
# For each of the below match-ups, choose the group that is more likely to vote for Bill Clinton. You can calculate this using the percentage of each group that intends to vote for Clinton (vote).
#
# Another way to think about this: Given that a respondent is a Democrat, there is a ____ percent chance they will vote for Clinton. How does this value change if the respondent is a Republican?

# %%
Clintonvote = df[df['vote'] == 0]

DemocratVote = Clintonvote[Clintonvote['party'] == 'Democrat']
RepublicanVote = Clintonvote[Clintonvote['party'] == 'Republican']
IndependentVote = Clintonvote[Clintonvote['party'] == 'Independent']
Demogroup = len(DemocratVote)
Repubgroup = len(RepublicanVote)
Indepengroup = len(IndependentVote)

total_democrats = len(df[df['party'] == 'Democrat'])
total_republicans = len(df[df['party'] == 'Republican'])
total_independents = len(df[df['party'] == 'Independent'])

democrat_percent = Demogroup / total_democrats * 100
republican_percent = Repubgroup / total_republicans * 100
independent_percent = Indepengroup / total_independents * 100

print(f"The Democrat group gave {democrat_percent:.2f} % votes to Clinton")
print(f"The Republican group gave {republican_percent:.2f} % votes to Clinton")
print(f"The Independent group gave {independent_percent:.2f} % votes to Clinton")
# Out:
# The Democrat group gave 96.32 % votes to Clinton
# The Republican group gave 10.46 % votes to Clinton
# The Independent group gave 63.18 % votes to Clinton

# %% [markdown]
# Which match-up was the closest? Which had the biggest difference?
#
# Democrats or Republicans
# People younger than 44 or People 44 and older
# People who watch TV news at least 6 days a week or People who watch TV news less than 3 days a week
# People who live somewhere with a population greater than the average respondent or People who live in a place with a population equal to or less than the average respondent

# %%
democrats_party=df[df['party']=='Democrat']
republic_party=df[df['party']=='Republican']
democrat_percent = (democrats_party['vote'] == 0).mean() * 100
republican_percent = (republic_party['vote'] == 0).mean() * 100

print("Democrats voted for Clinton:", democrat_percent, "%")
print("Republicans voted for Clinton:", republican_percent, "%")
# Out:
# Democrats voted for Clinton: 96.3157894736842 %
# Republicans voted for Clinton: 10.461538461538462 %

# %%
Younger=df[df['age']<44]
Older=df[df['age']>=44]
YoungGroup=(Younger['vote']==1).mean()*100
OldGroup=(Older['vote']==1).mean()*100

print("Young people voted for Clinton:", YoungGroup, "%")
print("Elder people voted for Clinton:", OldGroup, "%")
# Out:
# Young people voted for Clinton: 40.51724137931034 %
# Elder people voted for Clinton: 42.70833333333333 %

# %%
WeeklyTv=df[df['TVnews']==6]
HalfWeek=df[df['TVnews']==3]
Group1=(WeeklyTv['vote']==1).mean()*100
Group2=(HalfWeek['vote']==1).mean()*100

print("Those who watch the TV news 6 days a week :", Group1, "%")
print("Those who watch the TV news 3 days a week :", Group2, "%")
# Out:
# Those who watch the TV news 6 days a week : 59.375 %
# Those who watch the TV news 3 days a week : 30.693069306930692 %

# %%
AveragePop=df['popul'].mean()
HighPopul=df[df['popul']>AveragePop]
LowPopul=df[df['popul']<AveragePop]
GroupHigh=(HighPopul['vote']==1).mean()*100
GroupLow=(LowPopul['vote']==1).mean()*100

print("Those who live in highly populated region :", GroupHigh, "%")
print("Those who live in low populated region :", GroupLow, "%")
# Out:
# Those who live in highly populated region : 27.659574468085108 %
# Those who live in low populated region : 44.08468244084682 %

# %% [markdown]
# 5. Grouping Data Exercise
# Use the groupby() method to bucket respondents by age_group. Which age group is the most conservative? Which watches TV news the least?

# %%
conserved=df.groupby('age_group')
mean_conserved=conserved['ClinLR'].mean()
#mean_conserved2=conserved2.mean()
most_cons=mean_conserved.idxmax()
print(most_cons)
#print(mean_conserved2)
# Out:
# 18-24

# %%
conserved=df.groupby('age_group').mean()
most=conserved['ClinLR'].sort_values(ascending=False)
most
most2=conserved['selfLR'].sort_values(ascending=False)
most2
print(conserved['TVnews'].sort_values(ascending = True))
# Out:
# age_group
# 18-24       2.358491
# 25-34       2.570652
# 35-44       3.118367
# 45-54       3.916667
# 55-64       4.516129
# Above 65    5.523529
# Name: TVnews, dtype: float64
# <ipython-input-46-6d987f277b1c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   conserved=df.groupby('age_group').mean()

# %%
income_quants = list(df['income'].quantile(q=[0.2, 0.4, 0.6, 0.8, 1]))
def get_income_quant(df):

  if df['income'] <= income_quants[0]:
    return "Q1"
  elif df['income'] <= income_quants[1]:
    return "Q2"
  elif df['income'] <= income_quants[2]:
    return "Q3"
  elif df["income"] <= income_quants[3]:
    return "Q4"
  else:
    return "Q5"

# Apply it to the df and make a new column
df['income_quant'] = df.apply(get_income_quant, axis=1)

# %%
avg_by_income_quant = df.groupby(["income_quant"]).mean()
avg_by_income_quant
# Out:
# <ipython-input-48-ea97060f9013>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_by_income_quant = df.groupby(["income_quant"]).mean()
#                    popul    TVnews    selfLR    ClinLR    DoleLR       PID  \
# income_quant
# Q1            369.210526  4.047847  4.282297  3.444976  5.105263  2.215311
# Q2            253.068966  3.812808  4.295567  2.955665  5.315271  2.458128
# Q3            407.956522  3.409938  4.099379  2.913043  5.484472  2.739130
# Q4            254.216749  3.674877  4.497537  2.689655  5.458128  3.349754
# Q5            258.327381  3.595238  4.422619  2.619048  5.684524  3.571429
#
#                     age      educ     income      vote  logpopul
# income_quant
# Q1            50.009569  3.722488   7.004785  0.272727  2.994887
# Q2            48.266010  4.246305  14.896552  0.374384  2.350556
# Q3            45.583851  4.571429  17.931677  0.434783  2.182491
# Q4            45.128079  4.862069  20.507389  0.502463  2.722019
# Q5            45.589286  5.636905  23.089286  0.523810  1.945313

# %% [markdown]
# 6. Voting Across the Aisle
# We are interested in learning more about respondents who's political views differ strongly from the candidate they expect to vote for. Using selfLR, vote, ClinLR, and DoleLR, work through the following questions. Your interpretation may differ from the answer key.
#
# What is the largest recorded difference between a respondent's political leaning and their impression of their intended candidate's political leaning?
# How many respondents exhibit a difference of that magnitude?
# Make a separate DataFrame called sway that only includes voters who exhibit a difference greater than |3|.
# Among those in sway, are respondents more likely to be voting for a candidate more conservative or more liberal than their own political leaning?
# In sway, which candidate is the more popular choice?

# %%
if df['vote'].all():
  df['sway_diff']=df['selfLR'] - df['ClinLR']
else:
  df['sway_diff']=df['selfLR'] - df['DoleLR']
df.sort_values(by='sway_diff', ascending=False, key=abs)
# Out:
#       popul  TVnews  selfLR  ClinLR  DoleLR  PID   age  educ  income  vote  \
# 205     2.0     7.0     1.0     2.0     7.0  1.0  66.0   4.0    12.0   0.0
# 560     1.0     7.0     1.0     2.0     7.0  1.0  55.0   4.0    19.0   0.0
# 441    45.0     0.0     1.0     2.0     7.0  0.0  31.0   4.0    17.0   0.0
# 126  2800.0     0.0     1.0     1.0     7.0  0.0  38.0   3.0     9.0   0.0
# 469     0.0     3.0     1.0     2.0     7.0  2.0  67.0   7.0    17.0   0.0
# ..      ...     ...     ...     ...     ...  ...   ...   ...     ...   ...
# 573     1.0     3.0     6.0     1.0     6.0  4.0  49.0   6.0    20.0   1.0
# 152    55.0     7.0     4.0     5.0     4.0  1.0  71.0   2.0    11.0   0.0
# 153     0.0     2.0     4.0     4.0     4.0  0.0  67.0   1.0    11.0   0.0
# 577    34.0     4.0     6.0     2.0     6.0  6.0  30.0   6.0    20.0   1.0
# 786    16.0     7.0     6.0     2.0     6.0  6.0  45.0   6.0    22.0   1.0
#
#      logpopul        party age_group income_quant  sway_diff
# 205  0.741937     Democrat  Above 65           Q1       -6.0
# 560  0.095310     Democrat     55-64           Q3       -6.0
# 441  3.808882     Democrat     25-34           Q3       -6.0
# 126  7.937410     Democrat     35-44           Q1       -6.0
# 469 -2.302585  Independent  Above 65           Q3       -6.0
# ..        ...          ...       ...          ...        ...
# 573  0.095310  Independent     45-54           Q4        0.0
# 152  4.009150     Democrat  Above 65           Q1        0.0
# 153 -2.302585     Democrat  Above 65           Q1        0.0
# 577  3.529297   Republican     25-34           Q4        0.0
# 786  2.778819   Republican     45-54           Q5        0.0
#
# [944 rows x 15 columns]

# %%
sway = df[df['sway_diff'].abs() >= 3]
print(sway.describe())
print(f"{len(sway[sway['sway_diff'] > 0])} respondents perceive their candidate as more conservative than them.")
print(f"{len(sway[sway['sway_diff'] < 0])} respondents perceive their candidate as more liberal than them.")
print(f"{len(sway[sway['vote'] == 0])} respondents are voting for Clinton.")
print(f"{len(sway[sway['vote'] == 1])} respondents are voting for Dole.")
# Out:
#              popul      TVnews      selfLR      ClinLR      DoleLR  \
# count   264.000000  264.000000  264.000000  264.000000  264.000000
# mean    338.049242    3.625000    2.969697    3.132576    5.810606
# std    1043.689890    2.633417    1.281274    1.167298    1.503520
# min       0.000000    0.000000    1.000000    1.000000    1.000000
# 25%       4.000000    1.000000    2.000000    2.000000    6.000000
# 50%      40.000000    3.000000    3.000000    3.000000    6.000000
# 75%     170.000000    7.000000    3.000000    4.000000    7.000000
# max    7300.000000    7.000000    7.000000    7.000000    7.000000
#
#               PID         age        educ      income        vote    logpopul  \
# count  264.000000  264.000000  264.000000  264.000000  264.000000  264.000000
# mean     1.003788   44.196970    4.799242   15.924242    0.030303    3.048862
# std      1.291970   15.421056    1.562828    5.943487    0.171745    3.036151
# min      0.000000   19.000000    1.000000    1.000000    0.000000   -2.302585
# 25%      0.000000   33.000000    3.000000   13.000000    0.000000    1.410987
# 50%      1.000000   41.500000    5.000000   17.000000    0.000000    3.691376
# 75%      1.000000   53.000000    6.000000   20.250000    0.000000    5.136386
# max      6.000000   91.000000    7.000000   24.000000    1.000000    8.895643
#
#         sway_diff
# count  264.000000
# mean    -2.840909
# std      2.485944
# min     -6.000000
# 25%     -4.000000
# 50%     -3.000000
# 75%     -3.000000
# max      6.000000
# 31 respondents perceive their candidate as more conservative than them.
# 233 respondents perceive their candidate as more liberal than them.
# 256 respondents are voting for Clinton.
# 8 respondents are voting for Dole.
